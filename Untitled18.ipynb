# %%
d={'a':200,'b':300,'c':400}
def somme(x):
    som=0
    for i in x:
        som=som+ d[i]
    return som

# %%
somme(d)
# Out:
# 900

# %%
d={'a':200,'b':300,'c':400}
def moyenne(x):
    return sum(x.values())//len(x)

# %%
moyenne(d)
# Out:
# 300

# %%
d={'a':200,'b':300,'c':400}
def nbr_elmt(x):
    return len(x)

# %%
nbr_elmt(d)
# Out:
# 3

# %%
b 
def elmt(x):
    cpt=0
    for i in x:
        if x[i]>200:
            cpt=cpt+ 1
    return cpt

# %%
elmt(d)
# Out:
# 2
