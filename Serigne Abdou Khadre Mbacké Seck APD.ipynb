# %% [markdown]
# Exercice 1

# %%
t=input('Veillez saisir ici votre phrase ')
d={}
for i in t:
    som=0
    for j in t:
        if i==j:
            som+=1
            d[i]=som
print(d)
# Out:
# bien saisir ici votre phrasela maman de fatou
# {'l': 1, 'a': 4, ' ': 3, 'm': 2, 'n': 1, 'd': 1, 'e': 1, 'f': 1, 't': 1, 'o': 1, 'u': 1}

# %% [markdown]
# Exercice 2

# %%
x=int(input("Entrer une valeur  "))
som=0
s=0
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
    if ap==2:
        som=som+ i
    for z in range(1,x+1):
        v=z//i
    s=s+v
print("La somme des nombres parfaits est égale à ",s)
print("La somme des nombre paire est egale à ",som)
# Out:
# Entrer une valeur  4
# La somme des nombres parfaits est égale à  8
# La somme des nombre paire est egale à  5

# %% [markdown]
# Exercice 3

# %%
x=set( input("Entrer votre premier chaine de caractére "))
v=set(input("Saisie la deuxieme "))
z=x^v
list(z)
# Out:
# Entrer votre première chaîne de caractèrela mame
# Saisie la deuxièmefilemed
# ['f', ' ', 'a', 'd', 'i']

# %% [markdown]
# Exercice 4

# %%
x=int(input())
d={}
for i in range(1,x+1):
    d[i]=pow(i,2)
print(d)
# Out:
# 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# Exercice 5

# %%
def tupl(t):
    t=list(input("Veillez saisir votre liste "))
    s=0
    d=()
    v=[]
    c=[]
    for i in t:
        s=s+ 1
        if s%2==0:
            v.append(i)
        else:
            c.append(i)
    t=(v,c)
    print(t)
tupl(t)
# Out:
# Veillez saisir votre liste cest la guerre
# (['e', 't', 'l', ' ', 'u', 'r', 'e'], ['c', 's', ' ', 'a', 'g', 'e', 'r'])

# %% [markdown]
# Exercice 6

# %%
a=int(input('Entrer la valeur de a '))
b=int(input('Entrer la valeur de b '))
c=int(input('Entrer la valeur de c '))
if a==0:
    print("L'equation n'admet pas de solution car a est nul")
else:
    d=b*b-(4*a+4*c)
    if d<0:
        print("l'equation admet deux solution x1 et x2")
    elif d>0:
        print("L'equation admet une seul solution -b/a")
    else:
        print("L'equation n'admet pas de solution")
# Out:
# Entrer la valeur de a 0
# Entrer la valeur de b 4
# Entrer la valeur de c 5
# L'equation n'admet pas de solution car a est nul
