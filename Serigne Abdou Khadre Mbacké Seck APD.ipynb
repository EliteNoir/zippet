# %% [markdown]
# Exercice 1

# %%
t=input('Veillez saisir ici votre phrase ')
d={}
for i in t:
    som=0
    for j in t:
        if i==j:
            som+=1
            d[i]=som
print(d)
# Out:
# bien saisir ici votre phrasela maman de fatou
# {'l': 1, 'a': 4, ' ': 3, 'm': 2, 'n': 1, 'd': 1, 'e': 1, 'f': 1, 't': 1, 'o': 1, 'u': 1}

# %% [markdown]
# Exercice 2

# %%
x=int(input("Entrer une valeur  "))
som=0
s=0
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
   for i in range(1,x+1):
    ap=0
    for j in range(1,i):
        if i%j==0:
            ap=ap+ j
    if ap==i:
        v=v+i
print(v) 
    if ap==2:
        som=som+ i
print("La somme des nombres parfaits est égale à ",s)
print("La somme des nombre premier est egale à ",som)
# Out:
# Entrer une valeur  30
# La somme des nombres parfaits est égale à  18
# La somme des nombre paire est egale à  0

# %% [markdown]
# Exercice 3

# %%
x=set( input("Entrer votre premier chaine de caractére "))
v=set(input("Saisie la deuxieme "))
z=x^v
list(z)
# Out:
# Entrer votre premier chaine de caractére UTFYGG
# Saisie la deuxieme DVKHG
# ['D', 'U', 'F', 'K', 'H', 'V', 'Y', 'T']

# %% [markdown]
# Exercice 4

# %%
x=int(input())
d={}
for i in range(1,x+1):
    d[i]=pow(i,2)
print(d)
# Out:
# 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# Exercice 5

# %%
def tupl(t):
    t=list(input("Veillez saisir votre liste "))
    s=0
    v=[]
    c=[]
    for i in t:
        s=s+ 1
        if s%2==0:
            v.append(i)
        else:
            c.append(i)
    t=(v,c)
    print(t)
tupl(t)
# Out:
# Veillez saisir votre liste JE SUIE
# (['E', 'S', 'I', ' '], ['J', ' ', 'U', 'E'])

# %% [markdown]
# Exercice 6

# %%
a=int(input('Entrer la valeur de a '))
b=int(input('Entrer la valeur de b '))
c=int(input('Entrer la valeur de c '))
if a==0:
    print("L'equation n'admet pas de solution car a est nul")
else:
    d=b*b-(4*a+4*c)
    if d<0:
        print("l'equation admet deux solution x1 et x2")
    elif d>0:
        print("L'equation admet une seul solution -b/a")
    else:
        print("L'equation n'admet pas de solution")
# Out:
# Entrer la valeur de a 0
# Entrer la valeur de b 4
# Entrer la valeur de c 5
# L'equation n'admet pas de solution car a est nul

# %%
#Nombre parfait
x=int(input())
for i in range(0,x):
    apt=0
    for j in (1,x):
        if i%j==0:
            apt=apt+ i
    if apt==i:
        print(i)
# Out:
# 6
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x=int(input())
s=0
v=0
for i in range(1,x+1):
    ap=0
    for j in range(1,i):
        if i%j==0:
            ap=ap+ j
    if ap==i:
        v=v+i
print(v)
# Out:
# 30
# 34

# %%
x=int(input())
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
    if ap==2:
        print(i)
# Out:
# 10
# 2
# 3
# 5
# 7

# %%
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
    if ap==2:
        print(i)

# %%
t=input("saisie une chaine de caractere")
d={}
for i in t:
    som=0
    for j in t:
        if i==j:
            som=som+ 1
            d[i]=som
print(d)
# Out:
# saisie une chaine de caractereJE SUIS
# {'J': 1, 'E': 1, ' ': 1, 'S': 2, 'U': 1, 'I': 1}

# %%
x=set( input("Entrer votre premier chaine de caractére "))
x
# Out:
# Entrer votre premier chaine de caractére hifvid
# {'d', 'f', 'h', 'i', 'v'}

# %%
x=input()
y=input()
c=[]
for i in x:
    if i not in x and i not in c:
        c.append(i)
print(c)
# Out:
# irfrf
# hfu"tade
# []
