# %% [markdown]
# Exercice

# %% [markdown]
# Soit un dictionnaire note:
#     note{'Aliou':[10,3,4],'Astou':[14,16,17],'Demba':[13,16,18]}
# 1)Ecrire une fonction qui renvoie le majore de la classe.
# 2) Ecrire une fonction qui renvoie la plus petite moyennes supperieure ou egale a 14
# 3) Ecrire une fonctio, qui renvoie le dernier de la classe

# %%
note={'Aliou':[10,3,4],'Demba':[13,16,16],'Astou':[14,16,17],'Aliou':[10,3,4]}
def Majore(Mo):
    for i in note:
        Moyenne={i:sum(note[i])/len(note[i])}
        print(Mo)
        majore=max(Mo)
print(majore," est le majore de ca promotion")

# %%
# Out:
# {'Aliou': 5.666666666666667}
# {'Demba': 15.0}
# {'Astou': 15.666666666666666}
# Astou  est le majore de ca promotion
