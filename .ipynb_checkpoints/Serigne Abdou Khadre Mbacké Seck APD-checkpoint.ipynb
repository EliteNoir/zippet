# %% [markdown]
# Exercice 1

# %% [markdown]
# Exercice 2

# %%
x=int(input("Entrer un nombre  "))
som=0
s=0
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
    if ap==2:
        som=som+ i
    for z in range(1,x+1):
        v=z//i
    print(v)
    s=s+v
    if s==x:
        print("La somme des nombres parfaits est égale à ",s)
print("La somme des nombre paire est egale à ",som)
# Out:
# Entrer un nom  3
# 3
# La somme des nombres parfaits est égale à  3
# 1
# 1
# La somme des nombre paire est egale à  5

# %% [markdown]
# Exercice 3

# %%
x=6
for i in range(1,x+1):
    if x%i==0:
        s=s+i
    print(v)
# Out:
# 6
# 3
# 2
# 1
# 1
# 1

# %% [markdown]
# Exercice 4
