# %%
 
x=int(input("donner la longeur"))
y=int(input("donner la largeur"))
aire=input(x*y)
print(aire)
perimetre=input((x+y)*2)
print(perimetre)
# Out:
# donner la longeur5
# donner la largeur6
# 115
# 5
