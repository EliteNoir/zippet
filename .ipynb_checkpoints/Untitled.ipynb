# %%
print ("entrer deux valeur")
# Out:
# entrer deux valeur

# %%
x=int(input())
y=int(input())
# Out:
# 4
# 5

# %%
print ("le somme des deux valleurs est egale à",(x+y))
# Out:
# le somme des deux valleurs est egale à 9

# %%
a="Abdou Khadre"
print (a)
# Out:
# Abdou Khadre

# %%
type(a)
# Out:
# str

# %%
a=int(input("donner un nombre: "))
if a<0:
    print(a,"est negatif")
else:
    print(a,"est positif")
# Out:
# donner un nombre: -3
# -3 est negatif

# %%
a=(input("Quelle est votre genre F ou M"))
F=str
M=str
if a==F:
    print("vous etes une femme")
else:
    print("vous etes une homme")
# Out:
# Quelle est votre genre F ou MM
# vous etes une homme

# %%
a=int(input("donner un nombre: "))
if a<10:
    print(a,"est inferieur a dix")
elif a>10:
    print(a,"est superieur a dix")
else:
    print("le nombre est 10")
# Out:
# donner un nombre: 0
# 0 est inferieur a la disaine

# %%
a=(input("Entrer votre Metier: "))
b=(input("Entrer votre sexe: "))
c=(input("Entrer votre nom: "))
if b=="f"or b=="F":
    print("Mme",c)
else:
    print("C'est un homme")
# Out:
# Entrer votre Metier: APD
# Entrer votre sexe: M
# Entrer votre nom: seck
# C'est un homme

# %%
APD
