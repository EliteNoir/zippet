# %%
x=int(input())
for i in x:
    print(i)
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 x=int(input())
# ----> 2 for i in x:
#       3     print(i)
#
# TypeError: 'int' object is not iterable

# %%
x=int(input("Entrer un nombre "))
print('Nombre prmier inferieur')
p=0
for i in range(1,x+1):
    if x=int(input()):
    p=p+ 1
print(i)
# Out:
# Entrer un nombre 3
# Nombre prmier inferieur
# 4
