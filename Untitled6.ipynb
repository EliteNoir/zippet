# %% [markdown]
# exercice 1

# %%
x=int(input("entre"))
y=int(input("entrer"))
c=x
x=y
y=c
print(x,y)
# Out:
# entre3
# entrer5
# 5 3

# %% [markdown]
# Exercice 2

# %%
x=int(input())
print("la valeur absolue de ",x,"est",abs(x))
# Out:
# -4
# la valeur absolue de  -4 est 4

# %% [markdown]
# Exercice 3

# %%
x=int(input())
y=int(input())
z=int(input())
s=x+y+z
m=s//3
print(m)
# Out:
# 2
# 2
# 2
# 2

# %% [markdown]
# Exercice 4

# %%
mois=int(input("entrer le mois"))
if (mois == 1):
    print("Janvier")
if (mois == 2):
    print("Fevrier")
if (mois == 3):
    print("Mars")
if (mois == 4):
    print("Avril")
if (mois == 5):
    print("Mai")
if (mois == 6):
    print("Juin")
if (mois == 7):
    print("Juillet")
if (mois == 8):
    print("Août")
if (mois == 9):
    print("Septembre")
if (mois == 10):
    print("Octobre")
if (mois == 11):
    print("Novembre")
if(mois == 12):
    print("Decembre")
# Out:
# entrer le mois6
# Juin

# %%
H= int(input("Entrer l'heur"))
M=int(input("Entrer le minute"))
if(H == 23 and M == 59):
    print("Dans une minute il sera 00h : 00mn")
elif(M == 59):
    s=H+1
    print("Dans une minute il sera ",S,"h: 00mn")
else:
    V= M+1
    print("Dans une minute il sera ",H,"h: ",V,"mn" )
# Out:
# Entrer dans l'heure12
# Entrer dans la minute34
# Dans une minute il sera  12 h:  35 mn

# %%
H= int(input("Entrer l'heur"))
M=int(input("Entrer le minute"))
S=int(input("Entrer les seconde"))
if(H == 23 and M == 59 and S == 59):
    print("Dans une minute il sera 00h : 00mn 00s")
elif(M == 59 and S == 59):
    s=H+1
    print("Dans une minute il sera ",s,"h: 00mn 00s")
else:
    V= M+1
    print("Dans une minute il sera ",H,"h: ",V,"mn",S,"s")
# Out:
# Entrer dans l'heure12
# Entrer dans la minute59
# Entrer dans la seconde34
# Dans une minute il sera  12 h:  60 mn 34 s
