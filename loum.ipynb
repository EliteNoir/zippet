# %%
import time
import datetime as dt
import turtle
  
     
# create a turtle to display time
t = turtle.Turtle()
 
# create a turtle to create rectangle box
t1 = turtle.Turtle()
 
# create screen
s = turtle.Screen()
 
# set background color of the screen
s.bgcolor("white")
  
# obtain current hour, minute and second
# from the system
sec = dt.datetime.now().second
min = dt.datetime.now().minute
hr = dt.datetime.now().hour
t1.pensize(3)
t1.color('black')
t1.penup()
  
# set the position of turtle
t1.goto(-20, 0)
t1.pendown()
  
# create rectangular box
for i in range(2):
    t1.forward(200)
    t1.left(100)
    t1.forward(70)
    t1.left(90)
     
# hide the turtle
t1.hideturtle()
 
while True:
    t.hideturtle()
    t.clear()
    # display the time
    t.write(str(hr).zfill(2)
            +":"+str(min).zfill(2)+":"
            +str(sec).zfill(2),
            font =("Arial Narrow", 35, "bold"))
    time.sleep(1)
    sec+= 1
     
    if sec == 60:
        sec = 0
        min+= 1
     
    if min == 60:
        min = 0
        hr+= 1
     
    if hr == 13:
        hr = 1
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 42>()
#      41 while True:
#      42     t.hideturtle()
# ---> 43     t.clear()
#      44     # display the time
#      45     t.write(str(hr).zfill(2)
#      46             +":"+str(min).zfill(2)+":"
#      47             +str(sec).zfill(2),
#      48             font =("Arial Narrow", 35, "bold"))
#
# File ~\anaconda3\Nouveau dossier\lib\turtle.py:2643, in RawTurtle.clear(self)
#    2631 def clear(self):
#    2632     """Delete the turtle's drawings from the screen. Do not move turtle.
#    2633
#    2634     No arguments.
#    (...)
#    2641     >>> turtle.clear()
#    2642     """
# -> 2643     self._clear()
#    2644     self._update()
#
# File ~\anaconda3\Nouveau dossier\lib\turtle.py:2621, in RawTurtle._clear(self)
#    2619 self._fillitem = self._fillpath = None
#    2620 for item in self.items:
# -> 2621     self.screen._delete(item)
#    2622 self.currentLineItem = self.screen._createline()
#    2623 self.currentLine = []
#
# File ~\anaconda3\Nouveau dossier\lib\turtle.py:556, in TurtleScreenBase._delete(self, item)
#     552 def _delete(self, item):
#     553     """Delete graphics item from canvas.
#     554     If item is"all" delete all graphics items.
#     555     """
# --> 556     self.cv.delete(item)
#
# File <string>:1, in delete(self, *args, **kw)
#
# File ~\anaconda3\Nouveau dossier\lib\tkinter\__init__.py:2823, in Canvas.delete(self, *args)
#    2821 def delete(self, *args):
#    2822     """Delete items identified by all tag or ids contained in ARGS."""
# -> 2823     self.tk.call((self._w, 'delete') + args)
#
# TclError: invalid command name ".!canvas"
