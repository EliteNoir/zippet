# %% [markdown]
# Exercice 1:

# %%
X=int(input("Donner une valeur"))
Y=int(input("Donner une autre valeur"))
print("les valeur saise sont:" ,X,"et" ,Y)
C=X
X=Y
Y=C
print("l'inverse des valeur saise sont:" ,X,"et" ,Y)
# Out:
# Donner une valeur5
# Donner une autre valeur7
# les valeur saise sont: 5 et 7
# l'inverse des valeur saise sont: 7 et 5

# %% [markdown]
# Exercice 2:

# %%
A=in
# Out:
# Donner une valeur -7
# le valeur absolue de  -7 est egale à 7

# %% [markdown]
# Exercie 3:

# %%
a=int(input("Donner une valeur "))
b=int(input("Donner une deuxieme valeur "))
c=int(input("Donner une troisieme valeur "))
print("La moyenne des valeur saisie egale: ",((a+b+c)//3))
# Out:
# Donner une valeur 3
# Donner une deuxieme valeur 6
# Donner une troisieme valeur 8
# La moyenne des valeur saisie egale:  5

# %% [markdown]
# EXERCICE 4:

# %%
tva=0.18

# %% [markdown]
# Exercice 5:

# %%
a=int(input("Donner une valeur "))
if a%2==0:
    print(a,"est un nombre paire")
else:
    print(a,"est impaire")
# Out:
# Donner une valeur 2
# 2 est un nombre paire

# %% [markdown]
# Exercice 6:

# %%
x=int(input("Saisie une valeur"))
y=int(input("Saisie une deuxieme valeur"))
z=int(input("Saisie une troisieme valeur"))
if x

# %%
def f(x):
    n=1
    for i in range(1,20):
        n=n*(x*x+i*i)/i
    return n
f(4)
# Out:
# 6.145379999556532e+20

# %%
def prmier(x):
    cpt=0
    for i in range(1,x+1):
        if x%i==0:
            cpt=cpt+ 1
    if cpt==2:
        print(x,"est prmier") 
prmier(3)
# Out:
# 3 est prmier

# %%
def pair(x):
    for i in range(x+1):
        if i%2==0:
            print(i)
pair(4)
# Out:
# 0
# 2
# 4

# %%
def som(a,b,c):
    return a+b+c
som(2,3,4)
# Out:
# 9
