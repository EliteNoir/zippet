# %%
L=[12,14,18,3,5]
L.append(15)
L.append(16)
L
L.insert(4,17)
L
L.remove(12)
L.remove(15)
L
m= 0
s= 0
for i in L:
    if i>=14:
        s=s+ 1
        S=i+ i
        m=S//s
print(S)
print(m)
L.sort()
L
# Out:
# 32
# 8
# [3, 5, 14, 16, 17, 18]

# %%
L.copie()
L
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 L.copie()
#       2 L
#
# AttributeError: 'list' object has no attribute 'copie'
