# %%
a=float(input())
print(pow(a,17))
# Out:
# 2
# 131072.0

# %%
range(18,a):
    print(a)
# Out:
#   Input In [7]
#     range(18,a):
#                 ^
# SyntaxError: invalid syntax

# %%
x=int(input())
y=int(input())
z=int(input())
if x==y:
    print(y)
elif y==z:
    print(z)
elif x==z:
    print(x)
else:
    print()
# Out:
# 2
# 4
# 5

# %%
a = int(input())
if a > 0:
    if a > 1:
        if a > 2:
            print(a-2)
        else:
            print(a-1)
    else:
        print(a)
else:
    print("Erreur")
# Out:
# 3
# 1

# %%
a = int(input())
if a > 0:
    if a > 1:
        if a > 2:
            print(a-2)
        else:
            print(a-1)
    else:
        print(a)
else:
    print("Erreur")
# Out:
# 0
# Erreur

# %%
a = int(input())
if a > 0:
    if a > 1:
        if a > 2:
            print(a-2)
        else:
            print(a-1)
    else:
        print(a)
else:
    print("Erreur")
# Out:
# 2
# 1

# %%
a = int(input())
if a > 0:
    if a > 1:
        if a > 2:
            print(a-2)
        else:
            print(a-1)
    else:
        print(a)
else:
    print("Erreur")
# Out:
# 1
# 1

# %%
a=int(input())
if a>0:
    if a==1:
        print("a vaut 1")
    if a<=0:
        print("a est egale ou inferieur a 0")
# Out:
# 1
# a vaut 1

# %%
a=int(input())
b=int(input())
c=int(input())
if c==1:
    print(a-b)
if c==3:
    print(a*b)
if c==4:
    print(pow(a,2)+b*a)
else:
    print("ERROR")
# Out:
# 2
# 5
# 4
# 14

# %%
a=int(input())
b=int(input())
m=(a+b)/2
print(m)
# Out:
# 2
# 2
# 2.0

# %%
from math import*
a=float(input())
b=float(input())
if a<0 or b<0:
    print("Erreur")
else:
    print(sqrt(a*b))
# Out:
# -2
# 4
# Erreur

# %%
i=0
while i < 10:
    if i >5:
        print(i)
    i=i+1
# Out:
# 6
# 7
# 8
# 9

# %%
i=0
while i < 10:
    if i == 5:
    elif i == 9:
        print(i)
    i=i+1
# Out:
#   Input In [70]
#     elif i == 9:
#     ^
# SyntaxError: invalid syntax

# %%
for i in range(11):
    if i%2 == 0:
        print(str(i)+" est pair")
    print(str(i)+" est impair")
# Out:
# 0 est pair
# 0 est impair
# 1 est impair
# 2 est pair
# 2 est impair
# 3 est impair
# 4 est pair
# 4 est impair
# 5 est impair
# 6 est pair
# 6 est impair
# 7 est impair
# 8 est pair
# 8 est impair
# 9 est impair
# 10 est pair
# 10 est impair

# %%
a = int(input())
b = int(input())
while(a,b):
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 a = int(input())
#       2 b = int(input())
#       3 while(a,b):
#
# File ~\anaconda3\Nouveau dossier\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\anaconda3\Nouveau dossier\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
# ...

# %%
a = int(input())
i = 1
for i in range(1,a+1):
    print(i)
    i += 1
# Out:
# 3
# 1
# 2
# 3

# %%
randrange(0,100,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 randrange(0,100,2)
#
# NameError: name 'randrange' is not defined

# %%
n=6
for i in range(1,n):
    print('x x x x x x')
    i=i- 1
# Out:
# x x x x x x
# x x x x x x
# x x x x x x
# x x x x x x
# x x x x x x

# %%
n=6
for i in range(1,n):
    print('o x x x x o')
# Out:
# o x x x x o
# o x x x x o
# o x x x x o
# o x x x x o
# o x x x x o

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2     a,b = swap(a, b)
#       3     return swap
# ----> 4 swap(a,b)
#
# NameError: name 'a' is not defined
