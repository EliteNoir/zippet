# %%
 
x=int(input("donner la longeur"))
y=int(input("donner la largeur"))
aire=(x*y)
print(aire)
perimetre=((x+y)*2)
print(perimetre)
# Out:
# donner la longeur5
# donner la largeur5
# 25
# 20

# %%
prenom=str(input("donner votre prenom"))
nom=str(input("donner votre nom"))
age=int(input("donner votre age"))
if(age < 18):
    print("age est mineur")
elif(age == 18):
    print("age est majeur")
else:
    print("age est adulte")
# Out:
# donner votre prenomdidier zo
# donner votre nomsagna
# donner votre age23
# age est adulte

# %%
a=int(input("donner un nombre"))
b=int(input("donner un nombre"))
produit=a*b
print(produit)
if(produit > 0):
    print("produit est positive")
else:
    print("produit est negative")
# Out:
# donner un nombre5
# donner un nombre5
# 25
# produit est positive

# %%
a=int(input("donner un nombre"))
k=int(input("donner un nombre"))
S=int(input("donner le nombre a verifier"))
if(a>k or k<a):
    print("n'est pas dans l'intervale")
else:
     print("est dans l'intervale")
# Out:
# donner un nombre5
# donner un nombre20
# donner le nombre a verifier15
# est dans l'intervale
