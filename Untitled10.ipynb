# %% [markdown]
# Exercice 1

# %%
a=int(input())
b=int(input())
c=int(input())
if c==1:
    print(a-b)
elif c==3:
    print(a*b)
elif c==4:
    print(pow(a,2)+b*a)
else:
    print("ERROR")
# Out:
# 3
# 5
# 12
# ERROR

# %% [markdown]
# Exercice 2

# %%
x=int(input("Entrer un nombre "))
print('Nombre prmier inferieur')
for i in range(1,x+1):
    ap=0
    for j in range(1,i+1):
        if i%j==0:
            ap=ap+ 1
    if ap==2:       
        print(i)
print("Nombre inferieur paire")
for i in range(1,x):
    if i%2==0:
        print(i)
# Out:
# Entrer un nombre 8
# Nombre prmier inferieur
# 2
# 3
# 5
# 7
# Nombre inferieur paire
# 2
# 4
# 6

# %% [markdown]
# Exercice 3

# %%
def prdegre(b,c):
    if b<0:
        print("l'equation n'admet pas de solution")
    else:
        s=-c/2*b
        print(s)
prdegre(3,7)
# Out:
# -10.5

# %% [markdown]
# Exercice 4

# %%
n=int(input("Entrer le nombre d'etudiant "))
for i in range(1,n+1):
    x=int(input("Saisisez les notes "))
    if x<14:
        print("NO ACQUISE")
    else:
        print("ACQUISE")
# Out:
# Entrer le nombre d'etudiant3
# Saisisez les notes5
# NO ACQUISE
# Saisisez les notes6
# NO ACQUISE
# Saisisez les notes14
# ACQUISE

# %% [markdown]
# Exercice 5

# %%
x=int (input("Entrer une valeur "))
for i in range(x):
    print(i)
