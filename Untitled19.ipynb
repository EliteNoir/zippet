# %%
machine={'Marque':'Dell','ram':'8G','processeur':'intel core i5','stockage':'500G'}
machine['stockage']='250G'
machine
# Out:
# ['Dell', '8G', 'intel core i5', '250G']

# %%
machine.values()
# Out:
# dict_values(['Dell', '8G', 'intel core i5', '250G'])

# %%
machine.keys()
# Out:
# dict_keys(['Marque', 'ram', 'processeur', 'stockage', "systeme d'exploitation"])

# %%
machine.items()
# Out:
# dict_items([('Marque', 'Dell'), ('ram', '8G'), ('processeur', 'intel core i5'), ('stockage', '250G')])

# %%
machine["systeme d'exploitation"]="Windows10"
machine
# Out:
# {'Marque': 'Dell',
#  'ram': '8G',
#  'processeur': 'intel core i5',
#  'stockage': '250G',
#  "systeme d'exploitation": 'Windows10'}

# %%
pc={'HP':11,'Acer':7,'Lenovo':17,'Dell':23}
Phone={'Samsung':22,'Iphone':9,'Other':13}
tablette={'Samsung':15,'Other':13}
pc|Phone|tablette
# Out:
# {'HP': 11,
#  'Acer': 7,
#  'Lenovo': 17,
#  'Dell': 23,
#  'Samsung': 15,
#  'Iphone': 9,
#  'Other': 13}

# %%
etudiant={'ndeye':13,'fatou':17,'issa':9,'aly':15,'adama':8,'dieynaba':14,'habib':16,'ibrhima':12,'khadim':13,'astou':15,'khadija':14,'omar':9,'keba':10,'lamine':12}
d={}
v={}
for i in etudiant:
    if etudiant[i]>14 or etudiant[i]==14:
        d[i]=(etudiant[i])
    if etudiant[i]<14:
        v[i]=(etudiant[i])
print(d)
print(v)
# Out:
# {'fatou': 17, 'aly': 15, 'dieynaba': 14, 'habib': 16, 'astou': 15, 'khadija': 14}
# {'ndeye': 13, 'issa': 9, 'adama': 8, 'ibrhima': 12, 'khadim': 13, 'omar': 9, 'keba': 10, 'lamine': 12}

# %% [markdown]
# EXO1
# Ecrire un programme qui teste qui si un mot est palindrome ou pas.
# exo2
# ecrire un programme qui demande un utilisteur de saisir un texte et de lui renvoyer un dictionnaire dont les clés sont les mot du text et les valeurs sont les longeur des mot qui compose le text.

# %%
d = set(input())
for i in d:
    if i!=' ':
        
        z=i+i
print(z)
# Out:
# fnfhf sgrgr

# %%
t=input("Veiller saisir ici votre phrase")
set(t)
m=str()
cpt=0
p={}
for i in t:
    if i==' ':
        cpt=0
        m=m+ i
    if i!=' ':
        cpt=cpt+ 1
        p[m]=cpt   
print(p)
# Out:
# Veiller saisir ici votre phrasehgf hhv frfied
# {'': 3, ' ': 3, '  ': 6}

# %%
t=input("Saisie un Mot")
inv = t[::-1]
if t==inv:
    print(t,"est palindrome")
else:
    print(t,"n'est pas palindrom")
# Out:
# Saisie un Motradar
# radar est palindrome

# %%
t="ceci est un texte simple"
set(t)
m=str()
cpt=0²
p={}
for i in t:
    m=m+ i
    if i==' ':
        p[m]=i+m   
print(p)
# Out:
# {'ceci ': ' ceci ', 'ceci est ': ' ceci est ', 'ceci est un ': ' ceci est un ', 'ceci est un texte ': ' ceci est un texte '}
